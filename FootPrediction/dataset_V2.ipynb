# %% [markdown]
# ## Import des modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Préparation du dataset

# %% [markdown]
# Les données de certaines saisons ne sont pas accessibles selon les pays. Il faut donc adapter a quels dataframes les fonctions seront appliquées

# %% [markdown]
# ## Ouverture des CSV

# %%
# Espagne
#df_00 = pd.read_csv('datasets/SP1-00.csv')
#df_01 = pd.read_csv('datasets/SP1-01.csv')
#df_02 = pd.read_csv('datasets/SP1-02.csv')
#df_03 = pd.read_csv('datasets/SP1-03.csv')
#df_04 = pd.read_csv('datasets/SP1-04.csv')
df_05 = pd.read_csv('datasets/SP1-05.csv')
df_06 = pd.read_csv('datasets/SP1-06.csv')
df_07 = pd.read_csv('datasets/SP1-07.csv')
df_08 = pd.read_csv('datasets/SP1-08.csv')
df_09 = pd.read_csv('datasets/SP1-09.csv')
df_10 = pd.read_csv('datasets/SP1-10.csv')
df_11 = pd.read_csv('datasets/SP1-11.csv')
df_12 = pd.read_csv('datasets/SP1-12.csv')
df_13 = pd.read_csv('datasets/SP1-13.csv')
df_14 = pd.read_csv('datasets/SP1-14.csv')
df_15 = pd.read_csv('datasets/SP1-15.csv')
df_16 = pd.read_csv('datasets/SP1-16.csv')
df_17 = pd.read_csv('datasets/SP1-17.csv')
df_18 = pd.read_csv('datasets/SP1-18.csv')
df_19 = pd.read_csv('datasets/SP1-19.csv')
df_20 = pd.read_csv('datasets/SP1-20.csv')
df_21 = pd.read_csv('datasets/SP1-21.csv')

# %%
# Italie
#df_00 = pd.read_csv('datasets/I1-00.csv')
#df_01 = pd.read_csv('datasets/I1-01.csv')
#df_02 = pd.read_csv('datasets/I1-02.csv')
#df_03 = pd.read_csv('datasets/I1-03.csv')
#df_04 = pd.read_csv('datasets/I1-04.csv')
df_05 = pd.read_csv('datasets/I1-05.csv')
df_06 = pd.read_csv('datasets/I1-06.csv')
df_07 = pd.read_csv('datasets/I1-07.csv')
df_08 = pd.read_csv('datasets/I1-08.csv')
df_09 = pd.read_csv('datasets/I1-09.csv')
df_10 = pd.read_csv('datasets/I1-10.csv')
df_11 = pd.read_csv('datasets/I1-11.csv')
df_12 = pd.read_csv('datasets/I1-12.csv')
df_13 = pd.read_csv('datasets/I1-13.csv')
df_14 = pd.read_csv('datasets/I1-14.csv')
df_15 = pd.read_csv('datasets/I1-15.csv')
df_16 = pd.read_csv('datasets/I1-16.csv')
df_17 = pd.read_csv('datasets/I1-17.csv')
df_18 = pd.read_csv('datasets/I1-18.csv')
df_19 = pd.read_csv('datasets/I1-19.csv')
df_20 = pd.read_csv('datasets/I1-20.csv')
df_21 = pd.read_csv('datasets/I1-21.csv')

# %%
# Allemagne
#df_00 = pd.read_csv('datasets/D1-00.csv')
#df_01 = pd.read_csv('datasets/D1-01.csv')
#df_02 = pd.read_csv('datasets/D1-02.csv')
#df_03 = pd.read_csv('datasets/D1-03.csv')
#df_04 = pd.read_csv('datasets/D1-04.csv')
#df_05 = pd.read_csv('datasets/D1-05.csv')
df_06 = pd.read_csv('datasets/D1-06.csv')
df_07 = pd.read_csv('datasets/D1-07.csv')
df_08 = pd.read_csv('datasets/D1-08.csv')
df_09 = pd.read_csv('datasets/D1-09.csv')
df_10 = pd.read_csv('datasets/D1-10.csv')
df_11 = pd.read_csv('datasets/D1-11.csv')
df_12 = pd.read_csv('datasets/D1-12.csv')
df_13 = pd.read_csv('datasets/D1-13.csv')
df_14 = pd.read_csv('datasets/D1-14.csv')
df_15 = pd.read_csv('datasets/D1-15.csv')
df_16 = pd.read_csv('datasets/D1-16.csv')
df_17 = pd.read_csv('datasets/D1-17.csv')
df_18 = pd.read_csv('datasets/D1-18.csv')
df_19 = pd.read_csv('datasets/D1-19.csv')
df_20 = pd.read_csv('datasets/D1-20.csv')
df_21 = pd.read_csv('datasets/D1-21.csv')

# %%
# France
#df_00 = pd.read_csv('datasets/F1-00.csv')
#df_01 = pd.read_csv('datasets/F1-01.csv')
#df_02 = pd.read_csv('datasets/F1-02.csv')
#df_03 = pd.read_csv('datasets/F1-03.csv')
#df_04 = pd.read_csv('datasets/F1-04.csv')
#df_05 = pd.read_csv('datasets/F1-05.csv')
#df_06 = pd.read_csv('datasets/F1-06.csv')
df_07 = pd.read_csv('datasets/F1-07.csv')
df_08 = pd.read_csv('datasets/F1-08.csv')
df_09 = pd.read_csv('datasets/F1-09.csv')
df_10 = pd.read_csv('datasets/F1-10.csv')
df_11 = pd.read_csv('datasets/F1-11.csv')
df_12 = pd.read_csv('datasets/F1-12.csv')
df_13 = pd.read_csv('datasets/F1-13.csv')
df_14 = pd.read_csv('datasets/F1-14.csv')
df_15 = pd.read_csv('datasets/F1-15.csv')
df_16 = pd.read_csv('datasets/F1-16.csv')
df_17 = pd.read_csv('datasets/F1-17.csv')
df_18 = pd.read_csv('datasets/F1-18.csv')
df_19 = pd.read_csv('datasets/F1-19.csv')
df_20 = pd.read_csv('datasets/F1-20.csv')
df_21 = pd.read_csv('datasets/F1-21.csv')

# %%
# Angleterre
#df_00 = pd.read_csv('datasets/E0-00.csv')
#df_01 = pd.read_csv('datasets/E0-01.csv')
#df_02 = pd.read_csv('datasets/E0-02.csv')
#df_03 = pd.read_csv('datasets/E0-03.csv')
#df_04 = pd.read_csv('datasets/E0-04.csv')
df_05 = pd.read_csv('datasets/E0-05.csv')
df_06 = pd.read_csv('datasets/E0-06.csv')
df_07 = pd.read_csv('datasets/E0-07.csv')
df_08 = pd.read_csv('datasets/E0-08.csv')
df_09 = pd.read_csv('datasets/E0-09.csv')
df_10 = pd.read_csv('datasets/E0-10.csv')
df_11 = pd.read_csv('datasets/E0-11.csv')
df_12 = pd.read_csv('datasets/E0-12.csv')
df_13 = pd.read_csv('datasets/E0-13.csv')
df_14 = pd.read_csv('datasets/E0-14.csv')
df_15 = pd.read_csv('datasets/E0-15.csv')
df_16 = pd.read_csv('datasets/E0-16.csv')
df_17 = pd.read_csv('datasets/E0-17.csv')
df_18 = pd.read_csv('datasets/E0-18.csv')
df_19 = pd.read_csv('datasets/E0-19.csv')
df_20 = pd.read_csv('datasets/E0-20.csv')
df_21 = pd.read_csv('datasets/E0-21.csv')

# %% [markdown]
# ### Retirer les lignes buggées

# %%
# France
df_13 = df_13.drop(df_13.index[-1])
df_15 = df_15.drop(df_15.index[-1])
# On retire la dernière journée de la saison covid qui est incomplète
# (C'est con Rennes avait gagné 5-0 contre Montpellier)
df_19 = df_19.drop(df_19.tail(9).index)

# %%
# Angleterre
df_14 = df_14.drop(df_14.index[-1])

# %%
# Italie
# On retire les lignes buggées
df_12 = df_12.drop(df_12.tail(3).index)
df_14 = df_14.drop(df_14.index[-1])
df_15 = df_15.drop(df_15.index[-1])

# %% [markdown]
# ### Retirer les colonnes inutiles

# %%
col = ['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR',
       'HS','AS','HST','AST','HC','AC','HF','AF','HY','AY','HR','AR',
       'WHH','WHD','WHA']

#df_00 = df_00[col]
#df_01 = df_01[col]
#df_02 = df_02[col]
#df_03 = df_03[col]
#df_04 = df_04[col]
df_05 = df_05[col]
df_06 = df_06[col]
df_07 = df_07[col]
df_08 = df_08[col]
df_09 = df_09[col]
df_10 = df_10[col]
df_11 = df_11[col]
df_12 = df_12[col]
df_13 = df_13[col]
df_14 = df_14[col]
df_15 = df_15[col]
df_16 = df_16[col]
df_17 = df_17[col]
df_18 = df_18[col]
df_19 = df_19[col]
df_20 = df_20[col]
df_21 = df_21[col]

# %% [markdown]
# ## Ajout des cartons

# %% [markdown]
# Fonction renvoyant un dataframe du cumul des cartons jaunes par journée, par équipe

# %%
def yellow_made(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de cartons jaunes
    for _, row in df.iterrows():
        yellow_home = row['HY']
        yellow_away = row['AY']
        teams[row['HomeTeam']].append(yellow_home)
        teams[row['AwayTeam']].append(yellow_away)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_yellow = pd.DataFrame(data = teams, index=colonnes).T
    df_yellow.insert(0, 0, 0)
    # On cumule le nombre de cartons
    for i in colonnes:
        df_yellow[i] = df_yellow[i] + df_yellow[i-1]
    return df_yellow

# %% [markdown]
# Fonction renvoyant un dataframe du cumul des cartons rouges par journée, par équipe

# %%
def red_made(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de cartons rouges
    for _, row in df.iterrows():
        red_home = row['HR']
        red_away = row['AR']
        teams[row['HomeTeam']].append(red_home)
        teams[row['AwayTeam']].append(red_away)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_red = pd.DataFrame(data = teams, index=colonnes).T
    df_red.insert(0, 0, 0)
    # On cumule le nombre de cartons
    for i in colonnes:
        df_red[i] = df_red[i] + df_red[i-1]
    return df_red

# %% [markdown]
# Fonction ajoutant les cartons par chaque équipe chaque journée

# %%
def get_cards(df, covid):
    # On récupère les dataframes de cartons par journée
    yellow_ma = yellow_made(df, covid)
    red_ma = red_made(df, covid)
    
    # On calcule le nombre de matches par journée
    matches_per_day = int(len(df)/(yellow_ma.shape[1]-1))

    # On initialise les tableaux
    day = 0
    H_yellow_ma = []
    A_yellow_ma = []
    H_red_ma = []
    A_red_ma = []

    # Pour chaque match, on ajoute les cartons
    for index, row in df.iterrows():
        H_yellow_ma.append(yellow_ma[day][row['HomeTeam']])
        A_yellow_ma.append(yellow_ma[day][row['AwayTeam']])
        H_red_ma.append(red_ma[day][row['HomeTeam']])
        A_red_ma.append(red_ma[day][row['AwayTeam']])
        # On incrémente day quand on passe d'une journée à une autre
        if ((index + 1)% matches_per_day) == 0:
            day += 1
    
    df['HomeYellowlMade'] = H_yellow_ma
    df['AwayYellowMade'] = A_yellow_ma
    df['HomeRedMade'] = H_red_ma
    df['AwayRedMade'] = A_red_ma

    return df

# %%
#df_00 = get_cards(df_00, False)
#df_01 = get_cards(df_01, False)
#df_02 = get_cards(df_02, False)
#df_03 = get_cards(df_03, False)
#df_04 = get_cards(df_04, False)
df_05 = get_cards(df_05, False)
df_06 = get_cards(df_06, False)
df_07 = get_cards(df_07, False)
df_08 = get_cards(df_08, False)
df_09 = get_cards(df_09, False)
df_10 = get_cards(df_10, False)
df_11 = get_cards(df_11, False)
df_12 = get_cards(df_12, False)
df_13 = get_cards(df_13, False)
df_14 = get_cards(df_14, False)
df_15 = get_cards(df_15, False)
df_16 = get_cards(df_16, False)
df_17 = get_cards(df_17, False)
df_18 = get_cards(df_18, False)
df_19 = get_cards(df_19, False)
df_20 = get_cards(df_20, False)
df_21 = get_cards(df_21, False)

# %% [markdown]
# ## Ajout des fautes

# %% [markdown]
# Fonction renvoyant un dataframe du cumul des fautes réalisées par journée, par équipe

# %%
def foul_made(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de fautes réalisées
    for _, row in df.iterrows():
        foul_home = row['HF']
        foul_away = row['AF']
        teams[row['HomeTeam']].append(foul_home)
        teams[row['AwayTeam']].append(foul_away)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_foul = pd.DataFrame(data = teams, index=colonnes).T
    df_foul.insert(0, 0, 0)
    # On cumule le nombre de fautes
    for i in colonnes:
        df_foul[i] = df_foul[i] + df_foul[i-1]
    return df_foul

# %% [markdown]
# Fonction renvoyant un dataframe du cumul des fautes subies par journée, par équipe

# %%
def foul_conc(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de fautes subies
    for _, row in df.iterrows():
        foul_home = row['HF']
        foul_away = row['AF']
        teams[row['HomeTeam']].append(foul_away)
        teams[row['AwayTeam']].append(foul_home)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_foul = pd.DataFrame(data = teams, index=colonnes).T
    df_foul.insert(0, 0, 0)
    # On cumule le nombre de fautes
    for i in colonnes:
        df_foul[i] = df_foul[i] + df_foul[i-1]
    return df_foul

# %% [markdown]
# Fonction ajoutant les fautes par chaque équipe chaque journée

# %%
def get_fouls(df, covid):
    # On récupère les dataframes de fautes réalisées et subies par journée
    foul_ma = foul_made(df, covid)
    foul_co = foul_conc(df, covid)
    
    # On calcule le nombre de matches par journée
    matches_per_day = int(len(df)/(foul_ma.shape[1]-1))

    # On initialise les tableaux
    day = 0
    H_foul_ma = []
    H_foul_co = []
    A_foul_ma = []
    A_foul_co = []

    # Pour chaque match, on ajoute les fautes
    for index, row in df.iterrows():
        H_foul_ma.append(foul_ma[day][row['HomeTeam']])
        H_foul_co.append(foul_co[day][row['HomeTeam']])
        A_foul_ma.append(foul_ma[day][row['AwayTeam']])
        A_foul_co.append(foul_co[day][row['AwayTeam']])
        # On incrémente day quand on passe d'une journée à une autre
        if ((index + 1)% matches_per_day) == 0:
            day += 1
    
    df['HomeFoulMade'] = H_foul_ma
    df['HomeFoulConceded'] = H_foul_co
    df['AwayFoulMade'] = A_foul_ma
    df['AwayFoulConceded'] = A_foul_co

    return df

# %%
#df_00 = get_fouls(df_00, False)
#df_01 = get_fouls(df_01, False)
#df_02 = get_fouls(df_02, False)
#df_03 = get_fouls(df_03, False)
#df_04 = get_fouls(df_04, False)
df_05 = get_fouls(df_05, False)
df_06 = get_fouls(df_06, False)
df_07 = get_fouls(df_07, False)
df_08 = get_fouls(df_08, False)
df_09 = get_fouls(df_09, False)
df_10 = get_fouls(df_10, False)
df_11 = get_fouls(df_11, False)
df_12 = get_fouls(df_12, False)
df_13 = get_fouls(df_13, False)
df_14 = get_fouls(df_14, False)
df_15 = get_fouls(df_15, False)
df_16 = get_fouls(df_16, False)
df_17 = get_fouls(df_17, False)
df_18 = get_fouls(df_18, False)
df_19 = get_fouls(df_19, False)
df_20 = get_fouls(df_20, False)
df_21 = get_fouls(df_21, False)

# %% [markdown]
# ## Ajout des corners

# %% [markdown]
# Fonction renvoyant un dataframe du cumul des corners obtenus par journée, par équipe

# %%
def corner_made(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de corners obtenus
    for _, row in df.iterrows():
        corner_home = row['HC']
        corner_away = row['AC']
        teams[row['HomeTeam']].append(corner_home)
        teams[row['AwayTeam']].append(corner_away)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_corner = pd.DataFrame(data = teams, index=colonnes).T
    df_corner.insert(0, 0, 0)
    # On cumule le nombre de corners
    for i in colonnes:
        df_corner[i] = df_corner[i] + df_corner[i-1]
    return df_corner

# %% [markdown]
# Fonction renvoyant un dataframe du cumul des corners concédés par journée, par équipe

# %%
def corner_conc(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de corners concédés
    for _, row in df.iterrows():
        corner_home = row['HC']
        corner_away = row['AC']
        teams[row['HomeTeam']].append(corner_away)
        teams[row['AwayTeam']].append(corner_home)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_corner = pd.DataFrame(data = teams, index=colonnes).T
    df_corner.insert(0, 0, 0)
    # On cumule le nombre de corners
    for i in colonnes:
        df_corner[i] = df_corner[i] + df_corner[i-1]
    return df_corner

# %% [markdown]
# Fonction ajoutant les corners par chaque équipe chaque journée

# %%
def get_corners(df, covid):
    # On récupère les dataframes de buts marqués et encaissés par journée
    corner_ma = corner_made(df, covid)
    corner_co = corner_conc(df, covid)
    
    # On calcule le nombre de matches par journée
    matches_per_day = int(len(df)/(corner_ma.shape[1]-1))

    # On initialise les tableaux
    day = 0
    H_corner_ma = []
    H_corner_co = []
    A_corner_ma = []
    A_corner_co = []

    # Pour chaque match, on ajoute les corners
    for index, row in df.iterrows():
        H_corner_ma.append(corner_ma[day][row['HomeTeam']])
        H_corner_co.append(corner_co[day][row['HomeTeam']])
        A_corner_ma.append(corner_ma[day][row['AwayTeam']])
        A_corner_co.append(corner_co[day][row['AwayTeam']])
        # On incrémente day quand on passe d'une journée à une autre
        if ((index + 1)% matches_per_day) == 0:
            day += 1
    
    df['HomeCornerMade'] = H_corner_ma
    df['HomeCornerConceded'] = H_corner_co
    df['AwayCornerMade'] = A_corner_ma
    df['AwayCornerConceded'] = A_corner_co

    return df

# %%
#df_00 = get_corners(df_00, False)
#df_01 = get_corners(df_01, False)
#df_02 = get_corners(df_02, False)
#df_03 = get_corners(df_03, False)
#df_04 = get_corners(df_04, False)
df_05 = get_corners(df_05, False)
df_06 = get_corners(df_06, False)
df_07 = get_corners(df_07, False)
df_08 = get_corners(df_08, False)
df_09 = get_corners(df_09, False)
df_10 = get_corners(df_10, False)
df_11 = get_corners(df_11, False)
df_12 = get_corners(df_12, False)
df_13 = get_corners(df_13, False)
df_14 = get_corners(df_14, False)
df_15 = get_corners(df_15, False)
df_16 = get_corners(df_16, False)
df_17 = get_corners(df_17, False)
df_18 = get_corners(df_18, False)
df_19 = get_corners(df_19, False)
df_20 = get_corners(df_20, False)
df_21 = get_corners(df_21, False)

# %% [markdown]
# ## Ajout des buts marqués et encaissés

# %% [markdown]
# Fonction renvoyant un dataframe du cumul de buts marqués par journée, par équipe

# %%
def scored(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de buts marqués
    for _, row in df.iterrows():
        goal_home = row['FTHG']
        goal_away = row['FTAG']
        teams[row['HomeTeam']].append(goal_home)
        teams[row['AwayTeam']].append(goal_away)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_scored = pd.DataFrame(data = teams, index=colonnes).T
    df_scored.insert(0, 0, 0)
    # On cumule le nombre de buts marqués
    for i in colonnes:
        df_scored[i] = df_scored[i] + df_scored[i-1]
    return df_scored

# %% [markdown]
# Fonction renvoyant un dataframe du cumul de buts encaissés par journée, par équipe

# %%
def conceded(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de buts encaissés
    for _, row in df.iterrows():
        goal_home = row['FTHG']
        goal_away = row['FTAG']
        teams[row['HomeTeam']].append(goal_away)
        teams[row['AwayTeam']].append(goal_home)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_conc = pd.DataFrame(data = teams, index=colonnes).T
    df_conc.insert(0, 0, 0)
    # On cumule le nombre de buts encaissés
    for i in colonnes:
        df_conc[i] = df_conc[i] + df_conc[i-1]
    return df_conc

# %% [markdown]
# Fonction ajoutant les buts marqués et encaissés par chaque équipe chaque journée

# %%
def get_goals(df, covid):
    # On récupère les dataframes de buts marqués et encaissés par journée
    goal_sc = scored(df, covid)
    goal_co = conceded(df, covid)
    
    # On calcule le nombre de matches par journée
    matches_per_day = int(len(df)/(goal_sc.shape[1]-1))

    # On initialise les tableaux
    day = 0
    M_week = []
    H_scored = []
    H_conceded = []
    A_scored = []
    A_conceded = []
    H_diff = []
    A_diff = []

    # Pour chaque match, on ajoute les buts
    for index, row in df.iterrows():
        M_week.append(day+1)
        H_scored.append(goal_sc[day][row['HomeTeam']])
        H_conceded.append(goal_co[day][row['HomeTeam']])
        A_scored.append(goal_sc[day][row['AwayTeam']])
        A_conceded.append(goal_co[day][row['AwayTeam']])
        H_diff.append(goal_sc[day][row['HomeTeam']] - goal_co[day][row['HomeTeam']])
        A_diff.append(goal_sc[day][row['AwayTeam']] - goal_co[day][row['AwayTeam']])
        # On incrémente day quand on passe d'une journée à une autre
        if ((index + 1)% matches_per_day) == 0:
            day += 1
    
    df['MatchWeek'] = M_week
    df['HomeScored'] = H_scored
    df['HomeConceded'] = H_conceded
    df['AwayScored'] = A_scored
    df['AwayConceded'] = A_conceded
    df['HomeDiff'] = H_diff
    df['AwayDiff'] = A_diff

    return df

# %%
#df_00 = get_goals(df_00, False)
#df_01 = get_goals(df_01, False)
#df_02 = get_goals(df_02, False)
#df_03 = get_goals(df_03, False)
#df_04 = get_goals(df_04, False)
df_05 = get_goals(df_05, False)
df_06 = get_goals(df_06, False)
df_07 = get_goals(df_07, False)
df_08 = get_goals(df_08, False)
df_09 = get_goals(df_09, False)
df_10 = get_goals(df_10, False)
df_11 = get_goals(df_11, False)
df_12 = get_goals(df_12, False)
df_13 = get_goals(df_13, False)
df_14 = get_goals(df_14, False)
df_15 = get_goals(df_15, False)
df_16 = get_goals(df_16, False)
df_17 = get_goals(df_17, False)
df_18 = get_goals(df_18, False)
df_19 = get_goals(df_19, False)
df_20 = get_goals(df_20, False)
df_21 = get_goals(df_21, False)

# %% [markdown]
# ## Ajout des tirs

# %% [markdown]
# Fonction renvoyant un dataframe du cumul de tirs réalisés par journée, par équipe

# %%
def made_shot(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de tirs réalisés
    for _, row in df.iterrows():
        shot_home = row['HS']
        shot_away = row['AS']
        teams[row['HomeTeam']].append(shot_home)
        teams[row['AwayTeam']].append(shot_away)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_shot = pd.DataFrame(data = teams, index=colonnes).T
    df_shot.insert(0, 0, 0)
    # On cumule le nombre de tirs
    for i in colonnes:
        df_shot[i] = df_shot[i] + df_shot[i-1]
    return df_shot

# %% [markdown]
# Fonction renvoyant un dataframe du cumul de tirs cadrés réaliés par journée, par équipe

# %%
def made_shot_target(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de tirs cardrés réalisés
    for _, row in df.iterrows():
        shot_home = row['HST']
        shot_away = row['AST']
        teams[row['HomeTeam']].append(shot_home)
        teams[row['AwayTeam']].append(shot_away)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_shot = pd.DataFrame(data = teams, index=colonnes).T
    df_shot.insert(0, 0, 0)
    # On cumule le nombre de tirs cadrés
    for i in colonnes:
        df_shot[i] = df_shot[i] + df_shot[i-1]
    return df_shot

# %% [markdown]
# Fonction renvoyant un dataframe du cumul de tirs concédés par journée, par équipe

# %%
def conc_shot(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de tirs concédés
    for _, row in df.iterrows():
        shot_home = row['HS']
        shot_away = row['AS']
        teams[row['HomeTeam']].append(shot_away)
        teams[row['AwayTeam']].append(shot_home)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_shot = pd.DataFrame(data = teams, index=colonnes).T
    df_shot.insert(0, 0, 0)
    # On cumule le nombre de tirs
    for i in colonnes:
        df_shot[i] = df_shot[i] + df_shot[i-1]
    return df_shot

# %% [markdown]
# Fonction renvoyant un dataframe du cumul de tirs cadrés concédés par journée, par équipe

# %%
def conc_shot_target(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Journée par journée, on ajoute le nombre de tirs cadrés concédés
    for _, row in df.iterrows():
        shot_home = row['HST']
        shot_away = row['AST']
        teams[row['HomeTeam']].append(shot_away)
        teams[row['AwayTeam']].append(shot_home)
    # On ajoute ces données dans un dataframe équipe par équipe, journée par journée
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    df_shot = pd.DataFrame(data = teams, index=colonnes).T
    df_shot.insert(0, 0, 0)
    # On cumule le nombre de tirs cadrés
    for i in colonnes:
        df_shot[i] = df_shot[i] + df_shot[i-1]
    return df_shot

# %% [markdown]
# Fonction ajoutant les tirs par chaque équipe chaque journée

# %%
def get_shots(df, covid):
    # On récupère les dataframes de tirs
    shot_ma = made_shot(df, covid)
    shot_co = conc_shot(df, covid)
    shot_ma_target = made_shot_target(df, covid)
    shot_co_target = conc_shot_target(df, covid)
    
    # On calcule le nombre de matches par journée
    matches_per_day = int(len(df)/(shot_ma.shape[1]-1))

    # On initialise les tableaux
    day = 0
    H_shot_ma = []
    H_shot_co = []
    H_shot_ma_target = []
    H_shot_co_target = []
    A_shot_ma = []
    A_shot_co = []
    A_shot_ma_target = []
    A_shot_co_target = []

    # Pour chaque match, on ajoute les tirs
    for index, row in df.iterrows():
        H_shot_ma.append(shot_ma[day][row['HomeTeam']])
        H_shot_co.append(shot_co[day][row['HomeTeam']])
        H_shot_ma_target.append(shot_ma_target[day][row['HomeTeam']])
        H_shot_co_target.append(shot_co_target[day][row['HomeTeam']])
        A_shot_ma.append(shot_ma[day][row['AwayTeam']])
        A_shot_co.append(shot_co[day][row['AwayTeam']])
        A_shot_ma_target.append(shot_ma_target[day][row['AwayTeam']])
        A_shot_co_target.append(shot_co_target[day][row['AwayTeam']])
        # On incrémente day quand on passe d'une journée à une autre
        if ((index + 1)% matches_per_day) == 0:
            day += 1
    
    df['HomeMadeShot'] = H_shot_ma
    df['HomeConcededShot'] = H_shot_co
    df['HomeMadeShotTarget'] = H_shot_ma_target
    df['HomeConcededShotTarget'] = H_shot_co_target
    df['AwayMadeShot'] = A_shot_ma
    df['AwayConcededShot'] = A_shot_co
    df['AwayMadeShotTarget'] = A_shot_ma_target
    df['AwayConcededShotTarget'] = A_shot_co_target

    return df

# %%
#df_00 = get_shots(df_00, False)
#df_01 = get_shots(df_01, False)
#df_02 = get_shots(df_02, False)
#df_03 = get_shots(df_03, False)
#df_04 = get_shots(df_04, False)
df_05 = get_shots(df_05, False)
df_06 = get_shots(df_06, False)
df_07 = get_shots(df_07, False)
df_08 = get_shots(df_08, False)
df_09 = get_shots(df_09, False)
df_10 = get_shots(df_10, False)
df_11 = get_shots(df_11, False)
df_12 = get_shots(df_12, False)
df_13 = get_shots(df_13, False)
df_14 = get_shots(df_14, False)
df_15 = get_shots(df_15, False)
df_16 = get_shots(df_16, False)
df_17 = get_shots(df_17, False)
df_18 = get_shots(df_18, False)
df_19 = get_shots(df_19, False)
df_20 = get_shots(df_20, False)
df_21 = get_shots(df_21, False)

# %% [markdown]
# ## Ajout des points

# %% [markdown]
# Création d'un dataframe de points des équipes par journée

# %%
def result(df, covid):
    # Création du dictionnaire des équipes de la saison
    teams = {}
    for i in df['HomeTeam'].unique():
        teams[i] = []
    # Remplissage du ditionnaire (W:Victoire, L:Défaite, D:Match nul)
    for _, row in df.iterrows():
        if row['FTR'] == 'H':
            teams[row['HomeTeam']].append('W')
            teams[row['AwayTeam']].append('L')
        if row['FTR'] == 'D':
            teams[row['HomeTeam']].append('D')
            teams[row['AwayTeam']].append('D')
        if row['FTR'] == 'A':
            teams[row['HomeTeam']].append('L')
            teams[row['AwayTeam']].append('W')
    
    colonnes = list(range(1, 2*(len(teams)-1)+1))
    if covid:
        colonnes = list(range(1, 28))
    # Création du dataframe
    return pd.DataFrame(data=teams, index = colonnes).T

# %% [markdown]
# Fonction transformant un résultat textuel en points

# %%
def points(string):
    if string == 'W':
        return 3
    if string == 'D':
        return 1
    if string == 'L':
        return 0
    else:
        return 0

# %% [markdown]
# Création d'un dataframe des points cumulés par journée pour chaque équipe

# %%
def result_pts(results):
    # On transforme les résultats en points
    results = results.applymap(points)
    
    # On cumule le nombre de points
    for i in range(2,results.shape[1]+1):
        results[i] = results[i] + results[i-1]
    results.insert(0, 0, 0)

    return results

# %% [markdown]
# Ajout des points par journée au dataframe

# %%
def get_points(df, covid):
    res = result(df, covid)
    res = result_pts(res)

    # On initialise les tableaux
    day = 0
    H_pts = []
    A_pts = []
    
    # On calcule le nombre de matches par journée
    matches_per_day = int(len(df)/(res.shape[1]-1))

    # Pour chaque match, on ajoute les points
    for index, row in df.iterrows():
        H_pts.append(res[day][row['HomeTeam']])
        A_pts.append(res[day][row['AwayTeam']])
        # On incrémente day quand on passe d'une journée à une autre
        if ((index + 1)% matches_per_day) == 0:
            day += 1
    
    df['HomePoints'] = H_pts
    df['AwayPoints'] = A_pts

    return df

# %%
#df_00 = get_points(df_00, False)
#df_01 = get_points(df_01, False)
#df_02 = get_points(df_02, False)
#df_03 = get_points(df_03, False)
#df_04 = get_points(df_04, False)
df_05 = get_points(df_05, False)
df_06 = get_points(df_06, False)
df_07 = get_points(df_07, False)
df_08 = get_points(df_08, False)
df_09 = get_points(df_09, False)
df_10 = get_points(df_10, False)
df_11 = get_points(df_11, False)
df_12 = get_points(df_12, False)
df_13 = get_points(df_13, False)
df_14 = get_points(df_14, False)
df_15 = get_points(df_15, False)
df_16 = get_points(df_16, False)
df_17 = get_points(df_17, False)
df_18 = get_points(df_18, False)
df_19 = get_points(df_19, False)
df_20 = get_points(df_20, False)
df_21 = get_points(df_21, False)

# %% [markdown]
# ## Ajout de la forme de l'équipe

# %% [markdown]
# Fontion renvoyant un tableau contenant les 'num' résultats récents de chaque équipe par journée

# %%
def form(df, num, covid):
    res = result(df, covid)
    new_res = res.copy()
    # On ajoute les résultats récents
    for i in range(num, res.shape[1]+1):
        new_res[i] = ''
        j = 0
        while j < num:
            new_res[i] += res[i-j]
            j += 1
    return new_res

# %% [markdown]
# Ajout des `num` derniers résultats récents par journée au dataframe

# %%
def num_form(df, num, covid):
    forme = form(df, num, covid)
    # Création de listes de séries
    # Les premiers matchs, ou on ne peut pas avoir de série, sont marqués 'X'
    home = ['X' for i in range(num*int(len(forme)/2))]
    away = ['X' for i in range(num*int(len(forme)/2))]

    matches_per_day = int(len(df)/(forme.shape[1]-1))

    day = num
    #for i in range(num*int(len(forme)/2), len(df)):
    for index, row in df.iterrows():
        if index >= num*int(len(forme)/2):
            home_form = forme[day][row['HomeTeam']]
            away_form = forme[day][row['AwayTeam']]
            # On ajoute le 'num' dernier résultat
            home.append(home_form[num-1])
            away.append(away_form[num-1])
            # On incrémente day quand on passe d'une journée à une autre
            if ((index + 1)% matches_per_day) == 0:
                day += 1
    
    # On ajoute la série au dataframe
    df['HS'+str(num)] = home
    df['AS'+str(num)] = away

    return df

# %% [markdown]
# Ajout des derniers résultats récents par journée au dataframe

# %%
def get_form(df, covid):
    for i in range(1,6):
        df = num_form(df, i, covid)
    return df

# %%
#df_00 = get_form(df_00, False)
#df_01 = get_form(df_01, False)
#df_02 = get_form(df_02, False)
#df_03 = get_form(df_03, False)
#df_04 = get_form(df_04, False)
df_05 = get_form(df_05, False)
df_06 = get_form(df_06, False)
df_07 = get_form(df_07, False)
df_08 = get_form(df_08, False)
df_09 = get_form(df_09, False)
df_10 = get_form(df_10, False)
df_11 = get_form(df_11, False)
df_12 = get_form(df_12, False)
df_13 = get_form(df_13, False)
df_14 = get_form(df_14, False)
df_15 = get_form(df_15, False)
df_16 = get_form(df_16, False)
df_17 = get_form(df_17, False)
df_18 = get_form(df_18, False)
df_19 = get_form(df_19, True)
df_20 = get_form(df_20, False)
df_21 = get_form(df_21, False)

# %% [markdown]
# On combine les différentes saisons

# %%
df = pd.concat([#df_00,
                #df_01,
                #df_02,
                #df_03,
                #df_04,
                df_05,
                df_06,
                df_07,
                df_08,
                df_09,
                df_10,
                df_11,
                df_12,
                df_13,
                df_14,
                df_15,
                df_16,
                df_17,
                df_18,
                df_19,
                df_20,
                df_21], ignore_index=True)

# %% [markdown]
# Fonction transformant la série en un nombre de points (base de victoire à 3 points)

# %%
def points_streak(string):
    sum = 0
    for letter in string:
        sum += points(letter)
    return sum

# %% [markdown]
# On ajoute les séries de facon littéraire et numérique

# %%
df['HomeFormPtsStr'] = df['HS1'] + df['HS2'] + df['HS3'] + df['HS4'] + df['HS5']
df['AwayFormPtsStr'] = df['AS1'] + df['AS2'] + df['AS3'] + df['AS4'] + df['AS5']

df['HomeFormPts'] = df['HomeFormPtsStr'].apply(points_streak)
df['AwayFormPts'] = df['AwayFormPtsStr'].apply(points_streak)

# %% [markdown]
# Fonctions afin de vérifier s'il y a eu une série de victoires ou de défaites

# %%
def get_3GW(string):
    if string[-3:] == 'WWW':
        return 1
    else:
        return 0

def get_5GW(string):
    if string == 'WWWWW':
        return 1
    else:
        return 0

def get_3GL(string):
    if string[-3:] == 'LLL':
        return 1
    else:
        return 0

def get_5GL(string):
    if string == 'LLLLL':
        return 1
    else:
        return 0

# %% [markdown]
# On vérifie une éventuelle série

# %%
df['Home3GW'] = df['HomeFormPtsStr'].apply(get_3GW)
df['Home5GW'] = df['HomeFormPtsStr'].apply(get_5GW)
df['Home3GL'] = df['HomeFormPtsStr'].apply(get_3GL)
df['Home5GL'] = df['HomeFormPtsStr'].apply(get_5GL)

df['Away3GW'] = df['AwayFormPtsStr'].apply(get_3GW)
df['Away5GW'] = df['AwayFormPtsStr'].apply(get_5GW)
df['Away3GL'] = df['AwayFormPtsStr'].apply(get_3GL)
df['Away5GL'] = df['AwayFormPtsStr'].apply(get_5GL)

# %% [markdown]
# ## Dataset Final

# %% [markdown]
# On ne garde que certaines colonnes

# %%
col = ['Date','MatchWeek','HomeTeam','AwayTeam','FTR',
       'HomeYellowlMade', 'AwayYellowMade', 'HomeRedMade','AwayRedMade',
       'HomeFoulMade', 'HomeFoulConceded', 'AwayFoulMade','AwayFoulConceded',
       'HomeCornerMade', 'HomeCornerConceded','AwayCornerMade', 'AwayCornerConceded',
       'HomeScored','HomeConceded','AwayScored','AwayConceded','HomeDiff','AwayDiff',
       'HomePoints','AwayPoints',
       'HomeMadeShot','HomeConcededShot','HomeMadeShotTarget','HomeConcededShotTarget',
       'AwayMadeShot','AwayConcededShot','AwayMadeShotTarget','AwayConcededShotTarget',
       'HomeFormPtsStr','AwayFormPtsStr','HomeFormPts','AwayFormPts',
       'Home3GW','Home5GW','Home3GL','Home5GL',
       'Away3GW','Away5GW','Away3GL','Away5GL',
       'WHH','WHD','WHA']

df = df[col]

# %% [markdown]
# On exporte le dataset en CSV

# %%
df.to_csv('dataset_export.csv',index=False)

# %% [markdown]
# # Informations sur le dataset

# %% [markdown]
# Chargement du dataset

# %%
df = pd.read_csv('dataset_V2.csv')

# %%
len_with_NA = len(df)
df = df.dropna(inplace=False)
print(f"Il manque {len_with_NA-len(df)} lignes au dataset (sur {len_with_NA}) qui sont retirées par manque d'information")
# Out:
# Il manque 980 lignes au dataset (sur 31006) qui sont retirées par manque d'information

# %% [markdown]
# ## Matchs par saison

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# /var/folders/bg/vbvjjnmj0hv9wmb92ngxcq9m0000gn/T/ipykernel_1442/2394721818.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
match_saison = []
index_saison = []
for i in range(22):
    match_saison.append(len(df.loc[(df['Date']>='20'+str(i).zfill(2)+'-08-04') & (df['Date']<='20'+str(i+1).zfill(2)+'-08-03')]))
    index_saison.append('20'+str(i).zfill(2)+'/20'+str(i+1).zfill(2))

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
plt.title('Matches par Saison')
match_per_season_plot = sns.barplot(x = index_saison, y = match_saison)
match_per_season_plot.set(xlabel = 'Saisons', ylabel = 'Nombre de Matches')
# Out:
# [Text(0.5, 0, 'Saisons'), Text(0, 0.5, 'Nombre de Matches')]

# %% [markdown]
# ## Résultats des matches

# %% [markdown]
# ### Toutes données confondues

# %%
count = df['FTR'].value_counts()
plt.bar(x=['Victoire domicile','Match nul','Victoire extérieur'], height=count, color=['blue','orange','green'])
plt.title('Nombre des différents résultats')
plt.xlabel('Résultat du match')
plt.ylabel('Nombre de matches')
plt.show()

# %% [markdown]
# ### Par saison

# %%
prcent_saison = []
for i in range(22):
    new_df = df.copy()
    new_df = df.loc[(df['Date']>='20'+str(i).zfill(2)+'-08-04') & (df['Date']<='20'+str(i+1).zfill(2)+'-08-03')]
    count = new_df['FTR'].value_counts()
    prcent = count / count.sum() * 100
    prcent_saison.append(list(prcent))

df_prcent = pd.DataFrame(prcent_saison, columns=['Victoire domicile','Match nul','Victoire extérieur'], index=index_saison)

# %%
df_prcent.plot(kind='bar', figsize=(12,6))
plt.title('Pourcentages des résultats des matchs')
plt.xlabel('Saisons')
plt.ylabel('Pourcentage')
plt.show()

# %% [markdown]
# ## Moyenne des cotes

# %% [markdown]
# ### Toutes données confondues

# %%
plt.bar(x=['Victoire domicile','Match nul','Victoire extérieur'],
        height=[df['WHH'].mean(),df['WHD'].mean(),df['WHA'].mean()],
        color=['blue','orange','green'])
plt.title('Cotes moyennes des matchs')
plt.xlabel('Résultat du match')
plt.ylabel('Cote moyenne')
plt.show()

# %% [markdown]
# ### Par saison

# %%
cote_saison = []
for i in range(22):
    new_df = df.copy()
    new_df = df.loc[(df['Date']>='20'+str(i).zfill(2)+'-08-04') & (df['Date']<='20'+str(i+1).zfill(2)+'-08-03')]
    cote = [new_df['WHH'].mean(),new_df['WHD'].mean(),new_df['WHA'].mean()]
    cote_saison.append(list(cote))

df_cote = pd.DataFrame(cote_saison, columns=['Victoire domicile','Match nul','Victoire extérieur'], index=index_saison)

# %%
df_cote.plot(kind='bar', figsize=(12,6))
plt.title('Cotes moyennes des matchs')
plt.xlabel('Saisons')
plt.ylabel('Cote moyenne')
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(20,10)) 
sns.heatmap(df.corr(), annot= True)
# Out:
# /var/folders/bg/vbvjjnmj0hv9wmb92ngxcq9m0000gn/T/ipykernel_1714/3367888214.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot= True)
# <AxesSubplot: >

# %% [markdown]
# ## Scatter Matrix

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(15,15))
# Out:
# array([[<AxesSubplot: xlabel='MatchWeek', ylabel='MatchWeek'>,
#         <AxesSubplot: xlabel='HomeYellowlMade', ylabel='MatchWeek'>,
#         <AxesSubplot: xlabel='AwayYellowMade', ylabel='MatchWeek'>, ...,
#         <AxesSubplot: xlabel='WHH', ylabel='MatchWeek'>,
#         <AxesSubplot: xlabel='WHD', ylabel='MatchWeek'>,
#         <AxesSubplot: xlabel='WHA', ylabel='MatchWeek'>],
#        [<AxesSubplot: xlabel='MatchWeek', ylabel='HomeYellowlMade'>,
#         <AxesSubplot: xlabel='HomeYellowlMade', ylabel='HomeYellowlMade'>,
#         <AxesSubplot: xlabel='AwayYellowMade', ylabel='HomeYellowlMade'>,
#         ..., <AxesSubplot: xlabel='WHH', ylabel='HomeYellowlMade'>,
#         <AxesSubplot: xlabel='WHD', ylabel='HomeYellowlMade'>,
#         <AxesSubplot: xlabel='WHA', ylabel='HomeYellowlMade'>],
#        [<AxesSubplot: xlabel='MatchWeek', ylabel='AwayYellowMade'>,
#         <AxesSubplot: xlabel='HomeYellowlMade', ylabel='AwayYellowMade'>,
# ...
